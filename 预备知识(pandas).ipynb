# %% [markdown]
# <a href="https://colab.research.google.com/github/EfoodCN/d2l-zh/blob/master/%E9%A2%84%E5%A4%87%E7%9F%A5%E8%AF%86(pandas).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os

os.makedirs(os.path.join('..', 'data'), exist_ok=True)
data_file = os.path.join('..', 'data', 'house_tiny.csv')
with open(data_file, 'w') as f:
    f.write('NumRooms,Alley,Price\n')  # 列名
    f.write('NA,Pave,127500\n')  # 每行表示一个数据样本
    f.write('2,NA,106000\n')
    f.write('4,NA,178100\n')
    f.write('NA,NA,140000\n')

# %%
# 如果没有安装pandas，只需取消对以下行的注释来安装pandas
# !pip install pandas
import pandas as pd

data = pd.read_csv(data_file)
data, type(data)
# Out:
# (   NumRooms Alley   Price
#  0       NaN  Pave  127500
#  1       2.0   NaN  106000
#  2       4.0   NaN  178100
#  3       NaN   NaN  140000,
#  pandas.core.frame.DataFrame)

# %%
inputs, outputs = data.iloc[:,:1], data.iloc[:,2:]
inputs, outputs
# Out:
# (   NumRooms
#  0       NaN
#  1       2.0
#  2       4.0
#  3       NaN,
#      Price
#  0  127500
#  1  106000
#  2  178100
#  3  140000)

# %%
inputs = inputs.fillna(inputs.mean())
inputs
# Out:
#    NumRooms
# 0       3.0
# 1       2.0
# 2       4.0
# 3       3.0

# %%
inputs = data.iloc[:,:2]
print(inputs)
inputs = pd.get_dummies(inputs, dummy_na=True)
print(inputs)
# Out:
#    NumRooms Alley
# 0       NaN  Pave
# 1       2.0   NaN
# 2       4.0   NaN
# 3       NaN   NaN
#    NumRooms  Alley_Pave  Alley_nan
# 0       NaN        True      False
# 1       2.0       False       True
# 2       4.0       False       True
# 3       NaN       False       True

# %%
inputs = inputs.fillna(inputs.mean())
inputs
# Out:
#    NumRooms  Alley_Pave  Alley_nan
# 0       3.0        True      False
# 1       2.0       False       True
# 2       4.0       False       True
# 3       3.0       False       True

# %%
import torch

X = torch.tensor(inputs.to_numpy(dtype=float))
y = torch.tensor(outputs.to_numpy(dtype=float))
X, y, type(inputs)
# Out:
# (tensor([[3., 1., 0.],
#          [2., 0., 1.],
#          [4., 0., 1.],
#          [3., 0., 1.]], dtype=torch.float64),
#  tensor([[127500.],
#          [106000.],
#          [178100.],
#          [140000.]], dtype=torch.float64),
#  pandas.core.frame.DataFrame)
